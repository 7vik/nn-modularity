# %%
import os
import pickle
import platform
import random

import numpy as np
import torch
from transformer_lens import HookedTransformer

torch.set_grad_enabled(False)

SEED = 42

# %%
def is_mps_available() -> bool:
    """
    Safely check if MPS (Metal Performance Shaders) is available.
    """
    if platform.system() != "Darwin":  # MPS is only available on macOS
        return False

    # Check if the current PyTorch version has MPS support
    if not hasattr(torch, "backends") or not hasattr(torch.backends, "mps"):
        return False

    return torch.backends.mps.is_available()


def set_all_seeds(
    seed: int, deterministic: bool = True, warn_only: bool = False
) -> None:
    """
    Set all seeds and deterministic flags for reproducibility.

    Args:
        seed (int): The seed value to use for all random number generators
        deterministic (bool): Whether to enforce deterministic behavior
        warn_only (bool): If True, warning instead of error when deterministic
                         operations aren't supported
    """
    # Python RNG
    random.seed(seed)

    # NumPy RNG
    np.random.seed(seed)

    # PyTorch RNGs
    torch.manual_seed(seed)

    # Handle CUDA devices
    if torch.cuda.is_available():
        try:
            torch.cuda.manual_seed(seed)
            torch.cuda.manual_seed_all(seed)  # for multi-GPU
        except Exception as e:
            print(f"Warning: Could not set CUDA seeds: {str(e)}")

    # Handle MPS device (Apple Silicon)
    if is_mps_available():
        try:
            torch.mps.manual_seed(seed)
        except Exception as e:
            print(f"Warning: Could not set MPS seed: {str(e)}")

    # Environment variables
    os.environ["PYTHONHASHSEED"] = str(seed)

    if deterministic:
        try:
            # CUDA deterministic behavior
            if torch.cuda.is_available():
                os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
                torch.backends.cudnn.deterministic = True
                torch.backends.cudnn.benchmark = False

            # Set deterministic algorithms
            torch.use_deterministic_algorithms(True, warn_only=warn_only)

        except Exception as e:
            msg = f"Warning: Could not enable deterministic mode. Error: {str(e)}"
            if not warn_only:
                raise RuntimeError(msg)
            print(msg)


def get_device() -> torch.device:
    """
    Get the most appropriate PyTorch device available.

    Returns:
        torch.device: The preferred device (CUDA > MPS > CPU)
    """
    if torch.cuda.is_available():
        return torch.device("cuda")
    if is_mps_available():
        return torch.device("mps")
    return torch.device("cpu")

# %%
set_all_seeds(SEED, warn_only=True)
device = get_device()
model_name = "EleutherAI/pythia-1.4b"
model: HookedTransformer = HookedTransformer.from_pretrained(
    model_name, device=device
).eval()
# Out:
# The `GPTNeoXSdpaAttention` class is deprecated in favor of simply modifying the `config._attn_implementation`attribute of the `GPTNeoXAttention` class! It will be removed in v4.48
# Loaded pretrained model EleutherAI/pythia-1.4b into HookedTransformer

# %%
bank = {
    "city-country": {
        "bank": {
            "Bangkok": "Thailand",
            "Beijing": "China",
            "Buenos Aires": "Argentina",
            "Cape Town": "South Africa",
            "Hong Kong": "China",
            "Kuala Lumpur": "Malaysia",
            "Los Angeles": "United States",
            "Mexico City": "Mexico",
            "New Delhi": "India",
            "New York City": "United States",
            "Paris": "France",
            "Rio de Janeiro": "Brazil",
            "Rome": "Italy",
            "San Francisco": "United States",
            "St. Petersburg": "Russia",
            "Sydney": "Australia",
            "Tokyo": "Japan",
            "Toronto": "Canada",
        },
        "prompt": "%s is a city in the country of",
    },
    "city-continent": {
        "bank": {
            "Bangkok": "Asia",
            "Beijing": "Asia",
            "Buenos Aires": "South America",
            "Cape Town": "Africa",
            "Hong Kong": "Asia",
            "Kuala Lumpur": "Asia",
            "Los Angeles": "North America",
            "Mexico City": "North America",
            "New Delhi": "Asia",
            "New York City": "North America",
            "Paris": "Europe",
            "Rio de Janeiro": "South America",
            "Rome": "Europe",
            "San Francisco": "North America",
            "St. Petersburg": "Europe",
            "Sydney": "Oceania",
            "Tokyo": "Asia",
            "Toronto": "North America",
        },
        "prompt": "%s is a city in the continent of",
    },
    "city-language": {
        "bank": {
            "Bangkok": "Thai",
            "Beijing": "Chinese",
            "Buenos Aires": "Spanish",
            "Cape Town": "Afrikaans",
            "Kuala Lumpur": "Malay",
            "Los Angeles": "English",
            "Mexico City": "Spanish",
            "New Delhi": "Hindi",
            "New York City": "English",
            "Paris": "French",
            "Rio de Janeiro": "Portuguese",
            "Rome": "Italian",
            "San Francisco": "English",
            "St. Petersburg": "Russian",
            "Sydney": "English",
            "Tokyo": "Japanese",
            "Toronto": "English",
        },
        "prompt": "%s is a city where the language spoken is",
    },
    "occupation-duty": {
        "bank": {
            "to plan and design the construction of buildings": "architect",
            "to represent clients in court during trial": "lawyer",
            "to diagnose and treat issues related to the teeth": "dentist",
            "to create clothing and accessories according to current trends": "fashion designer",
            "to report news and information": "journalist",
            "to educate students in a classroom setting": "teacher",
            "to capture images using cameras": "photographer",
            "to lead and guide a team of representatives, employees, or workers": "manager",
            "to code, test, and maintain computer programs and applications": "software developer",
            "to prepare and cook food in a professional kitchen": "chef",
            "to care for patients in a medical setting and assist doctors": "nurse",
            "to enforce laws and protect citizens from crime": "police officer",
            "to repair and maintain vehicles and machinery in a workshop, garage, or factory": "mechanic",
            "to conduct research and experiments in a laboratory setting": "scientist",
            "to create visual art using various mediums, such as paint, clay, or digital tools": "artist",
            "to play musical instruments and perform for audiences in various settings": "musician",
        },
        "prompt": "My duties are %s; I am a",
    },
    "object-color": {
        "bank": {
            "apple": "red",
            "banana": "yellow",
            "carrot": "orange",
            "grape": "purple",
            "lemon": "yellow",
            "lime": "green",
            "orange": "orange",
            "pear": "green",
            "strawberry": "red",
            "tomato": "red",
            "blueberry": "blue",
            "cherry": "red",
            "eggplant": "purple",
            "kiwi": "brown",
            "peach": "orange",
            "plum": "purple",
            "watermelon": "green",
            "avocado": "green",
        },
        "prompt": "The color of the %s is usually",
    },
    "object-size": {
        "bank": {
            "diamond": "millimeter",
            "bamboo": "meter",
            "axe": "meter",
            "gopher": "centimeter",
            "saffron": "millimeter",
            "lime": "centimeter",
            "turmeric": "centimeter",
            "lion": "meter",
            "violet": "centimeter",
            "starfish": "centimeter",
            "charcoal": "centimeter",
            "turquoise": "centimeter",
            "flamingo": "meter",
            "pig": "meter",
            "cornmeal": "centimeter",
            "blackberry": "centimeter",
        },
        "prompt": 'Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of %s is commonly expressed in "',
    },
}

# %%
def make_prompt(entity: str = "city", target: str = "country", num_prompts: int = 30):
    pair = "{entity}-{target}".format(entity=entity, target=target)
    data = bank[pair]
    pairs = data["bank"]
    prompt = data["prompt"]
    cities = list(pairs.keys())

    # Generate N 3-shot prompts: "A is a city in the country of B. C is a city in the country of D. E is a city in the country of " ground_truth = F
    prompts = []
    for i in range(num_prompts):
        # Randomly sample 3 cities from the list + 1 ground truth city to be queried (all different)
        cities_sampled = torch.randperm(len(cities))[:4]
        countries_sampled = [pairs[cities[i]] for i in cities_sampled]
        ground_truth = countries_sampled[-1]

        # Generate the prompt
        prompt_instance = (
            prompt % cities[cities_sampled[0]]
            + " "
            + countries_sampled[0]
            + ". "
            + prompt % cities[cities_sampled[1]]
            + " "
            + countries_sampled[1]
            + ". "
            + prompt % cities[cities_sampled[2]]
            + " "
            + countries_sampled[2]
            + ". "
            + prompt % cities[cities_sampled[3]]
        )

        prompts.append((prompt_instance, ground_truth))
    return prompts

# %%
# # city - country
# city_country_prompts = make_prompt(entity="city", target="country", num_prompts=100)

# # city - continent
# city_continent_prompts = make_prompt(entity="city", target="continent", num_prompts=100)

# # city - language
# city_language_prompts = make_prompt(entity="city", target="language", num_prompts=100)

# # duty - occupation
# duty_occupation_prompts = make_prompt(
#     entity="occupation", target="duty", num_prompts=100
# )

# # object - color
# object_color_prompts = make_prompt(entity="object", target="color", num_prompts=100)

# # object - size
# object_size_prompts = make_prompt(entity="object", target="size", num_prompts=100)

# %%
# # Print some samples
# print(city_country_prompts[0])
# print(city_continent_prompts[0])
# print(city_language_prompts[0])
# print(duty_occupation_prompts[0])
# print(object_color_prompts[0])
# print(object_size_prompts[0])

# %%
# model.generate(
#     "She is living in Rome, therefore her country of residence is Italy. She is living in New Delhi, therefore her country of residence is India. She is living in Washington, therefore her country of residence is",
#     max_new_tokens=5,
#     temperature=1.0,
#     prepend_bos=True,
# )  # This will print the output of the model

# %%
# city_country_correct = 0
# city_country_retained = []
# for prompt, gt in city_country_prompts:
#     print(prompt)
#     generation = model.generate(
#         prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True
#     )
#     print(generation)

#     print("Ground truth: ", gt)
#     print("\n\n")
#     print("---------------------------------------------------")
#     if gt.startswith(generation[len(prompt) :].strip()):
#         city_country_correct += 1
#         city_country_retained.append((prompt, gt))

# print("Accuracy: ", city_country_correct / len(city_country_prompts))

# %%
# city_continent_correct = 0


# city_continent_retained = []
# for prompt, gt in city_continent_prompts:
#     print(prompt)
#     generation = model.generate(
#         prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True
#     )
#     print(generation)
#     print("Ground truth: ", gt)
#     print("\n\n")
#     print("---------------------------------------------------")
#     if gt.startswith(generation[len(prompt) :].strip()):
#         city_continent_correct += 1
#         city_continent_retained.append((prompt, gt))

# print("Accuracy: ", city_continent_correct / len(city_continent_prompts))

# %%
# city_language_correct = 0
# city_language_retained = []
# for prompt, gt in city_language_prompts:
#     print(prompt)
#     generation = model.generate(
#         prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True
#     )
#     print(generation)
#     print("Ground truth: ", gt)
#     print("\n\n")
#     print("---------------------------------------------------")
#     if gt.startswith(generation[len(prompt) :].strip()):
#         city_language_correct += 1
#         city_language_retained.append((prompt, gt))

# print("Accuracy: ", city_language_correct / len(city_language_prompts))

# %%
# duty_occupation_correct = 0
# duty_occupation_retained = []
# for prompt, gt in duty_occupation_prompts:
#     print(prompt)
#     generation = model.generate(
#         prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True
#     )
#     print(generation)
#     print("Ground truth: ", gt)
#     print("\n\n")
#     print("---------------------------------------------------")
#     if gt.startswith(generation[len(prompt) :].strip()):
#         duty_occupation_correct += 1
#         duty_occupation_retained.append((prompt, gt))

# print("Accuracy: ", duty_occupation_correct / len(duty_occupation_prompts))

# %%
# object_color_correct = 0
# object_color_retained = []
# for prompt, gt in object_color_prompts:
#     print(prompt)
#     generation = model.generate(
#         prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True
#     )
#     print(generation)
#     print("Ground truth: ", gt)
#     print("\n\n")
#     print("---------------------------------------------------")
#     if gt.startswith(generation[len(prompt) :].strip()):
#         object_color_correct += 1
#         object_color_retained.append((prompt, gt))

# print("Accuracy: ", object_color_correct / len(object_color_prompts))

# %%
# object_size_correct = 0
# object_size_retained = []
# for prompt, gt in object_size_prompts:
#     print(prompt)
#     generation = model.generate(
#         prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True
#     )
#     print(generation)
#     print("Ground truth: ", gt)
#     print("\n\n")
#     print("---------------------------------------------------")
#     if gt.startswith(generation[len(prompt) :].strip()):
#         object_size_correct += 1
#         object_size_retained.append((prompt, gt))

# print("Accuracy: ", object_size_correct / len(object_size_prompts))

# %%
# # Save in a pickle file the data {(entity-target): {accuracy : accuracy, retained: [(prompt, gt)], full_data: [(prompt, gt)]}}

# data = {
#     "city-country": {
#         "accuracy": city_country_correct / len(city_country_prompts),
#         "retained": city_country_retained,
#         "full_data": city_country_prompts,
#     },
#     "city-continent": {
#         "accuracy": city_continent_correct / len(city_continent_prompts),
#         "retained": city_continent_retained,
#         "full_data": city_continent_prompts,
#     },
#     "city-language": {
#         "accuracy": city_language_correct / len(city_language_prompts),
#         "retained": city_language_retained,
#         "full_data": city_language_prompts,
#     },
#     "occupation-duty": {
#         "accuracy": duty_occupation_correct / len(duty_occupation_prompts),
#         "retained": duty_occupation_retained,
#         "full_data": duty_occupation_prompts,
#     },
#     "object-color": {
#         "accuracy": object_color_correct / len(object_color_prompts),
#         "retained": object_color_retained,
#         "full_data": object_color_prompts,
#     },
#     "object-size": {
#         "accuracy": object_size_correct / len(object_size_prompts),
#         "retained": object_size_retained,
#         "full_data": object_size_prompts,
#     },
# }

# with open(f"{model_name}_prompt_data.pkl", "wb") as f:
#     pickle.dump(data, f)

# %%
# Load data from pkl
path = "/data/joan_velja/nn-modularity/language-models"
pkl_path = os.path.join(path, f"{model_name.split('/')[-1]}_prompt_data.pkl")

# %%
with open(pkl_path, "rb") as f:
    data = pickle.load(f)

# %%
full_data = {}
for keys in data.keys():
    full_data[keys] = data[keys]["full_data"]

# %%
# Eval harness : model on the prompts
def eval_model(model, data):
    correct = 0
    retained = {}
    for key in data.keys():
        key_correct = 0
        for prompt, gt in data[key]:
            generation = model.generate(
                prompt, max_new_tokens=1, temperature=0.0, prepend_bos=True, verbose=False
            )
            if gt.startswith(generation[len(prompt) :].strip()):
                correct += 1
                key_correct += 1
                if key not in retained:
                    retained[key] = []
                retained[key].append((prompt, gt))
        print(f"Accuracy for {key}: {key_correct / len(data[key])}")
    return correct / len(retained), retained

# %%
_, retained_pyt = eval_model(model, full_data)
# Out:
# Accuracy for city-country: 0.852
# Accuracy for city-continent: 0.858
# Accuracy for city-language: 0.868
# Accuracy for occupation-duty: 0.652
# Accuracy for object-color: 0.376
# Accuracy for object-size: 0.496

# %%
accuracies = {}
for key in full_data.keys():
    accuracies[key] = len(retained_pyt[key]) / len(full_data[key])

# %%
data
# Out:
# {'city-country': {'accuracy': 0.348,
#   'retained': [('Los Angeles is a city in the country of United States. Sydney is a city in the country of Australia. St. Petersburg is a city in the country of Russia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('San Francisco is a city in the country of United States. Hong Kong is a city in the country of China. Beijing is a city in the country of China. Mexico City is a city in the country of',
#     'Mexico'),
#    ('New York City is a city in the country of United States. Beijing is a city in the country of China. San Francisco is a city in the country of United States. Hong Kong is a city in the country of',
#     'China'),
#    ('Bangkok is a city in the country of Thailand. Rio de Janeiro is a city in the country of Brazil. Sydney is a city in the country of Australia. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Sydney is a city in the country of Australia. Rome is a city in the country of Italy. Toronto is a city in the country of Canada. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Cape Town is a city in the country of South Africa. Kuala Lumpur is a city in the country of Malaysia. Rome is a city in the country of Italy. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('New York City is a city in the country of United States. San Francisco is a city in the country of United States. Toronto is a city in the country of Canada. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Hong Kong is a city in the country of China. Rome is a city in the country of Italy. San Francisco is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('St. Petersburg is a city in the country of Russia. Paris is a city in the country of France. San Francisco is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('St. Petersburg is a city in the country of Russia. Los Angeles is a city in the country of United States. Buenos Aires is a city in the country of Argentina. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Tokyo is a city in the country of Japan. San Francisco is a city in the country of United States. Bangkok is a city in the country of Thailand. Toronto is a city in the country of',
#     'Canada'),
#    ('Paris is a city in the country of France. Los Angeles is a city in the country of United States. Tokyo is a city in the country of Japan. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Toronto is a city in the country of Canada. Paris is a city in the country of France. Sydney is a city in the country of Australia. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Tokyo is a city in the country of Japan. Rome is a city in the country of Italy. New York City is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('Los Angeles is a city in the country of United States. Toronto is a city in the country of Canada. San Francisco is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Cape Town is a city in the country of South Africa. Sydney is a city in the country of Australia. Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('San Francisco is a city in the country of United States. Beijing is a city in the country of China. New Delhi is a city in the country of India. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Bangkok is a city in the country of Thailand. Los Angeles is a city in the country of United States. Hong Kong is a city in the country of China. Tokyo is a city in the country of',
#     'Japan'),
#    ('New York City is a city in the country of United States. Beijing is a city in the country of China. Rio de Janeiro is a city in the country of Brazil. Sydney is a city in the country of',
#     'Australia'),
#    ('Rome is a city in the country of Italy. Beijing is a city in the country of China. Bangkok is a city in the country of Thailand. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('New Delhi is a city in the country of India. New York City is a city in the country of United States. Toronto is a city in the country of Canada. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Hong Kong is a city in the country of China. Los Angeles is a city in the country of United States. New Delhi is a city in the country of India. Toronto is a city in the country of',
#     'Canada'),
#    ('Rio de Janeiro is a city in the country of Brazil. Beijing is a city in the country of China. Kuala Lumpur is a city in the country of Malaysia. Bangkok is a city in the country of',
#     'Thailand'),
#    ('St. Petersburg is a city in the country of Russia. Rio de Janeiro is a city in the country of Brazil. Beijing is a city in the country of China. Tokyo is a city in the country of',
#     'Japan'),
#    ('Buenos Aires is a city in the country of Argentina. Sydney is a city in the country of Australia. Rome is a city in the country of Italy. Mexico City is a city in the country of',
#     'Mexico'),
#    ('New Delhi is a city in the country of India. Beijing is a city in the country of China. New York City is a city in the country of United States. Hong Kong is a city in the country of',
#     'China'),
#    ('Hong Kong is a city in the country of China. Rome is a city in the country of Italy. Los Angeles is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('New York City is a city in the country of United States. Beijing is a city in the country of China. Bangkok is a city in the country of Thailand. Mexico City is a city in the country of',
#     'Mexico'),
#    ('San Francisco is a city in the country of United States. Los Angeles is a city in the country of United States. Beijing is a city in the country of China. Sydney is a city in the country of',
#     'Australia'),
#    ('Tokyo is a city in the country of Japan. Kuala Lumpur is a city in the country of Malaysia. New Delhi is a city in the country of India. Beijing is a city in the country of',
#     'China'),
#    ('New Delhi is a city in the country of India. San Francisco is a city in the country of United States. Bangkok is a city in the country of Thailand. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Mexico City is a city in the country of Mexico. Bangkok is a city in the country of Thailand. New York City is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('Toronto is a city in the country of Canada. Hong Kong is a city in the country of China. Los Angeles is a city in the country of United States. Rome is a city in the country of',
#     'Italy'),
#    ('Los Angeles is a city in the country of United States. New Delhi is a city in the country of India. St. Petersburg is a city in the country of Russia. Beijing is a city in the country of',
#     'China'),
#    ('New Delhi is a city in the country of India. Bangkok is a city in the country of Thailand. Rome is a city in the country of Italy. Paris is a city in the country of',
#     'France'),
#    ('Rio de Janeiro is a city in the country of Brazil. Beijing is a city in the country of China. Los Angeles is a city in the country of United States. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Paris is a city in the country of France. Beijing is a city in the country of China. Bangkok is a city in the country of Thailand. Toronto is a city in the country of',
#     'Canada'),
#    ('Buenos Aires is a city in the country of Argentina. St. Petersburg is a city in the country of Russia. Kuala Lumpur is a city in the country of Malaysia. Beijing is a city in the country of',
#     'China'),
#    ('Cape Town is a city in the country of South Africa. New Delhi is a city in the country of India. Paris is a city in the country of France. Bangkok is a city in the country of',
#     'Thailand'),
#    ('St. Petersburg is a city in the country of Russia. Paris is a city in the country of France. Los Angeles is a city in the country of United States. Sydney is a city in the country of',
#     'Australia'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Toronto is a city in the country of Canada. Rome is a city in the country of Italy. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Paris is a city in the country of France. San Francisco is a city in the country of United States. Kuala Lumpur is a city in the country of Malaysia. Sydney is a city in the country of',
#     'Australia'),
#    ('Los Angeles is a city in the country of United States. Rio de Janeiro is a city in the country of Brazil. Beijing is a city in the country of China. Sydney is a city in the country of',
#     'Australia'),
#    ('Bangkok is a city in the country of Thailand. Buenos Aires is a city in the country of Argentina. Rome is a city in the country of Italy. Tokyo is a city in the country of',
#     'Japan'),
#    ('Hong Kong is a city in the country of China. San Francisco is a city in the country of United States. Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('St. Petersburg is a city in the country of Russia. Bangkok is a city in the country of Thailand. Tokyo is a city in the country of Japan. Paris is a city in the country of',
#     'France'),
#    ('Toronto is a city in the country of Canada. St. Petersburg is a city in the country of Russia. Buenos Aires is a city in the country of Argentina. Beijing is a city in the country of',
#     'China'),
#    ('Cape Town is a city in the country of South Africa. Mexico City is a city in the country of Mexico. New Delhi is a city in the country of India. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('Paris is a city in the country of France. Sydney is a city in the country of Australia. San Francisco is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('New Delhi is a city in the country of India. St. Petersburg is a city in the country of Russia. Beijing is a city in the country of China. Tokyo is a city in the country of',
#     'Japan'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of Mexico. Sydney is a city in the country of Australia. Bangkok is a city in the country of',
#     'Thailand'),
#    ('San Francisco is a city in the country of United States. Hong Kong is a city in the country of China. Paris is a city in the country of France. Tokyo is a city in the country of',
#     'Japan'),
#    ('St. Petersburg is a city in the country of Russia. Rio de Janeiro is a city in the country of Brazil. San Francisco is a city in the country of United States. Tokyo is a city in the country of',
#     'Japan'),
#    ('Rome is a city in the country of Italy. Cape Town is a city in the country of South Africa. Tokyo is a city in the country of Japan. Toronto is a city in the country of',
#     'Canada'),
#    ('Tokyo is a city in the country of Japan. Mexico City is a city in the country of Mexico. Cape Town is a city in the country of South Africa. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('New York City is a city in the country of United States. Beijing is a city in the country of China. Paris is a city in the country of France. Hong Kong is a city in the country of',
#     'China'),
#    ('Paris is a city in the country of France. New York City is a city in the country of United States. Rome is a city in the country of Italy. Bangkok is a city in the country of',
#     'Thailand'),
#    ('St. Petersburg is a city in the country of Russia. Buenos Aires is a city in the country of Argentina. Rome is a city in the country of Italy. Sydney is a city in the country of',
#     'Australia'),
#    ('Hong Kong is a city in the country of China. Tokyo is a city in the country of Japan. New York City is a city in the country of United States. Sydney is a city in the country of',
#     'Australia'),
#    ('Los Angeles is a city in the country of United States. Rome is a city in the country of Italy. New York City is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('San Francisco is a city in the country of United States. Cape Town is a city in the country of South Africa. Bangkok is a city in the country of Thailand. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Beijing is a city in the country of China. Paris is a city in the country of France. New Delhi is a city in the country of India. Hong Kong is a city in the country of',
#     'China'),
#    ('Paris is a city in the country of France. Bangkok is a city in the country of Thailand. Sydney is a city in the country of Australia. Beijing is a city in the country of',
#     'China'),
#    ('Beijing is a city in the country of China. St. Petersburg is a city in the country of Russia. Sydney is a city in the country of Australia. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Hong Kong is a city in the country of China. Rio de Janeiro is a city in the country of Brazil. Sydney is a city in the country of Australia. Beijing is a city in the country of',
#     'China'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Buenos Aires is a city in the country of Argentina. Tokyo is a city in the country of Japan. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Buenos Aires is a city in the country of Argentina. Hong Kong is a city in the country of China. Paris is a city in the country of France. Rome is a city in the country of',
#     'Italy'),
#    ('Cape Town is a city in the country of South Africa. Los Angeles is a city in the country of United States. Paris is a city in the country of France. Beijing is a city in the country of',
#     'China'),
#    ('Buenos Aires is a city in the country of Argentina. Paris is a city in the country of France. New Delhi is a city in the country of India. Toronto is a city in the country of',
#     'Canada'),
#    ('Hong Kong is a city in the country of China. Rome is a city in the country of Italy. Los Angeles is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('Buenos Aires is a city in the country of Argentina. Tokyo is a city in the country of Japan. Los Angeles is a city in the country of United States. Sydney is a city in the country of',
#     'Australia'),
#    ('St. Petersburg is a city in the country of Russia. San Francisco is a city in the country of United States. Kuala Lumpur is a city in the country of Malaysia. Sydney is a city in the country of',
#     'Australia'),
#    ('Bangkok is a city in the country of Thailand. Buenos Aires is a city in the country of Argentina. New York City is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('Sydney is a city in the country of Australia. New Delhi is a city in the country of India. Bangkok is a city in the country of Thailand. Toronto is a city in the country of',
#     'Canada'),
#    ('Los Angeles is a city in the country of United States. Paris is a city in the country of France. Beijing is a city in the country of China. Sydney is a city in the country of',
#     'Australia'),
#    ('Buenos Aires is a city in the country of Argentina. Rome is a city in the country of Italy. Tokyo is a city in the country of Japan. Mexico City is a city in the country of',
#     'Mexico'),
#    ('San Francisco is a city in the country of United States. New York City is a city in the country of United States. New Delhi is a city in the country of India. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('New Delhi is a city in the country of India. Kuala Lumpur is a city in the country of Malaysia. Los Angeles is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('Rome is a city in the country of Italy. Kuala Lumpur is a city in the country of Malaysia. Buenos Aires is a city in the country of Argentina. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Beijing is a city in the country of China. Paris is a city in the country of France. Los Angeles is a city in the country of United States. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Tokyo is a city in the country of Japan. Bangkok is a city in the country of Thailand. Mexico City is a city in the country of Mexico. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Los Angeles is a city in the country of United States. Paris is a city in the country of France. New Delhi is a city in the country of India. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Hong Kong is a city in the country of China. Cape Town is a city in the country of South Africa. Sydney is a city in the country of Australia. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Toronto is a city in the country of Canada. Rio de Janeiro is a city in the country of Brazil. New York City is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rio de Janeiro is a city in the country of Brazil. Cape Town is a city in the country of South Africa. Sydney is a city in the country of Australia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Toronto is a city in the country of Canada. Hong Kong is a city in the country of China. Bangkok is a city in the country of Thailand. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Beijing is a city in the country of China. Kuala Lumpur is a city in the country of Malaysia. Paris is a city in the country of France. Hong Kong is a city in the country of',
#     'China'),
#    ('Los Angeles is a city in the country of United States. Hong Kong is a city in the country of China. Rome is a city in the country of Italy. Toronto is a city in the country of',
#     'Canada'),
#    ('Rio de Janeiro is a city in the country of Brazil. Los Angeles is a city in the country of United States. New York City is a city in the country of United States. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Paris is a city in the country of France. Kuala Lumpur is a city in the country of Malaysia. Cape Town is a city in the country of South Africa. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('San Francisco is a city in the country of United States. Paris is a city in the country of France. Kuala Lumpur is a city in the country of Malaysia. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('New York City is a city in the country of United States. Bangkok is a city in the country of Thailand. Paris is a city in the country of France. New Delhi is a city in the country of',
#     'India'),
#    ('Rome is a city in the country of Italy. Buenos Aires is a city in the country of Argentina. Bangkok is a city in the country of Thailand. Beijing is a city in the country of',
#     'China'),
#    ('Hong Kong is a city in the country of China. Rio de Janeiro is a city in the country of Brazil. St. Petersburg is a city in the country of Russia. Beijing is a city in the country of',
#     'China'),
#    ('Buenos Aires is a city in the country of Argentina. Paris is a city in the country of France. Tokyo is a city in the country of Japan. Beijing is a city in the country of',
#     'China'),
#    ('New Delhi is a city in the country of India. Tokyo is a city in the country of Japan. San Francisco is a city in the country of United States. Sydney is a city in the country of',
#     'Australia'),
#    ('Rome is a city in the country of Italy. Toronto is a city in the country of Canada. St. Petersburg is a city in the country of Russia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Tokyo is a city in the country of Japan. Hong Kong is a city in the country of China. Los Angeles is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('Beijing is a city in the country of China. San Francisco is a city in the country of United States. Tokyo is a city in the country of Japan. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Bangkok is a city in the country of Thailand. Kuala Lumpur is a city in the country of Malaysia. Sydney is a city in the country of Australia. Beijing is a city in the country of',
#     'China'),
#    ('Rome is a city in the country of Italy. Toronto is a city in the country of Canada. Buenos Aires is a city in the country of Argentina. Sydney is a city in the country of',
#     'Australia'),
#    ('Paris is a city in the country of France. Buenos Aires is a city in the country of Argentina. Beijing is a city in the country of China. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Cape Town is a city in the country of South Africa. Hong Kong is a city in the country of China. St. Petersburg is a city in the country of Russia. Toronto is a city in the country of',
#     'Canada'),
#    ('San Francisco is a city in the country of United States. New York City is a city in the country of United States. Beijing is a city in the country of China. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Toronto is a city in the country of Canada. Kuala Lumpur is a city in the country of Malaysia. Beijing is a city in the country of China. Rome is a city in the country of',
#     'Italy'),
#    ('Hong Kong is a city in the country of China. Toronto is a city in the country of Canada. Buenos Aires is a city in the country of Argentina. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rio de Janeiro is a city in the country of Brazil. Bangkok is a city in the country of Thailand. San Francisco is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('Rome is a city in the country of Italy. San Francisco is a city in the country of United States. Mexico City is a city in the country of Mexico. Tokyo is a city in the country of',
#     'Japan'),
#    ('Toronto is a city in the country of Canada. Hong Kong is a city in the country of China. Tokyo is a city in the country of Japan. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Los Angeles is a city in the country of United States. Paris is a city in the country of France. New York City is a city in the country of United States. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Cape Town is a city in the country of South Africa. Mexico City is a city in the country of Mexico. Bangkok is a city in the country of Thailand. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('New York City is a city in the country of United States. Toronto is a city in the country of Canada. New Delhi is a city in the country of India. Tokyo is a city in the country of',
#     'Japan'),
#    ('Toronto is a city in the country of Canada. Buenos Aires is a city in the country of Argentina. St. Petersburg is a city in the country of Russia. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Tokyo is a city in the country of Japan. Buenos Aires is a city in the country of Argentina. Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Hong Kong is a city in the country of China. Kuala Lumpur is a city in the country of Malaysia. Los Angeles is a city in the country of United States. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('New York City is a city in the country of United States. Kuala Lumpur is a city in the country of Malaysia. Los Angeles is a city in the country of United States. Tokyo is a city in the country of',
#     'Japan'),
#    ('Paris is a city in the country of France. Tokyo is a city in the country of Japan. Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rome is a city in the country of Italy. New York City is a city in the country of United States. Mexico City is a city in the country of Mexico. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('New York City is a city in the country of United States. St. Petersburg is a city in the country of Russia. Paris is a city in the country of France. Beijing is a city in the country of',
#     'China'),
#    ('Cape Town is a city in the country of South Africa. Sydney is a city in the country of Australia. Rome is a city in the country of Italy. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Paris is a city in the country of France. Cape Town is a city in the country of South Africa. Rio de Janeiro is a city in the country of Brazil. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Kuala Lumpur is a city in the country of Malaysia. New Delhi is a city in the country of India. Buenos Aires is a city in the country of Argentina. Beijing is a city in the country of',
#     'China'),
#    ('Rome is a city in the country of Italy. Bangkok is a city in the country of Thailand. San Francisco is a city in the country of United States. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Rio de Janeiro is a city in the country of Brazil. Buenos Aires is a city in the country of Argentina. Beijing is a city in the country of China. Sydney is a city in the country of',
#     'Australia'),
#    ('Cape Town is a city in the country of South Africa. San Francisco is a city in the country of United States. St. Petersburg is a city in the country of Russia. Rome is a city in the country of',
#     'Italy'),
#    ('Toronto is a city in the country of Canada. Paris is a city in the country of France. Los Angeles is a city in the country of United States. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Beijing is a city in the country of China. Rome is a city in the country of Italy. Toronto is a city in the country of Canada. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Sydney is a city in the country of Australia. New Delhi is a city in the country of India. Rome is a city in the country of Italy. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Hong Kong is a city in the country of China. Toronto is a city in the country of Canada. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Rome is a city in the country of Italy. San Francisco is a city in the country of United States. Mexico City is a city in the country of Mexico. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('St. Petersburg is a city in the country of Russia. San Francisco is a city in the country of United States. Buenos Aires is a city in the country of Argentina. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('New Delhi is a city in the country of India. Sydney is a city in the country of Australia. San Francisco is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('New York City is a city in the country of United States. Paris is a city in the country of France. Buenos Aires is a city in the country of Argentina. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('Beijing is a city in the country of China. Bangkok is a city in the country of Thailand. New York City is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Sydney is a city in the country of Australia. Los Angeles is a city in the country of United States. Toronto is a city in the country of Canada. Beijing is a city in the country of',
#     'China'),
#    ('Buenos Aires is a city in the country of Argentina. New York City is a city in the country of United States. Paris is a city in the country of France. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Sydney is a city in the country of Australia. Tokyo is a city in the country of Japan. Los Angeles is a city in the country of United States. Beijing is a city in the country of',
#     'China'),
#    ('Hong Kong is a city in the country of China. Cape Town is a city in the country of South Africa. New Delhi is a city in the country of India. Toronto is a city in the country of',
#     'Canada'),
#    ('St. Petersburg is a city in the country of Russia. Toronto is a city in the country of Canada. Beijing is a city in the country of China. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Cape Town is a city in the country of South Africa. Sydney is a city in the country of Australia. Rome is a city in the country of Italy. Tokyo is a city in the country of',
#     'Japan'),
#    ('Los Angeles is a city in the country of United States. Mexico City is a city in the country of Mexico. Bangkok is a city in the country of Thailand. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Rio de Janeiro is a city in the country of Brazil. Mexico City is a city in the country of Mexico. Beijing is a city in the country of China. Bangkok is a city in the country of',
#     'Thailand'),
#    ('St. Petersburg is a city in the country of Russia. Los Angeles is a city in the country of United States. Sydney is a city in the country of Australia. Beijing is a city in the country of',
#     'China'),
#    ('Cape Town is a city in the country of South Africa. Los Angeles is a city in the country of United States. San Francisco is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('New York City is a city in the country of United States. Los Angeles is a city in the country of United States. Cape Town is a city in the country of South Africa. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rome is a city in the country of Italy. Hong Kong is a city in the country of China. Buenos Aires is a city in the country of Argentina. Tokyo is a city in the country of',
#     'Japan'),
#    ('Toronto is a city in the country of Canada. Paris is a city in the country of France. Buenos Aires is a city in the country of Argentina. Beijing is a city in the country of',
#     'China'),
#    ('San Francisco is a city in the country of United States. Paris is a city in the country of France. Tokyo is a city in the country of Japan. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('San Francisco is a city in the country of United States. New Delhi is a city in the country of India. Paris is a city in the country of France. Tokyo is a city in the country of',
#     'Japan'),
#    ('Los Angeles is a city in the country of United States. St. Petersburg is a city in the country of Russia. Tokyo is a city in the country of Japan. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rome is a city in the country of Italy. Cape Town is a city in the country of South Africa. San Francisco is a city in the country of United States. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Paris is a city in the country of France. St. Petersburg is a city in the country of Russia. Tokyo is a city in the country of Japan. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Toronto is a city in the country of Canada. Paris is a city in the country of France. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rio de Janeiro is a city in the country of Brazil. Beijing is a city in the country of China. Toronto is a city in the country of Canada. Tokyo is a city in the country of',
#     'Japan'),
#    ('Sydney is a city in the country of Australia. Los Angeles is a city in the country of United States. Tokyo is a city in the country of Japan. Toronto is a city in the country of',
#     'Canada'),
#    ('Los Angeles is a city in the country of United States. San Francisco is a city in the country of United States. Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Mexico City is a city in the country of Mexico. Paris is a city in the country of France. Tokyo is a city in the country of Japan. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('Cape Town is a city in the country of South Africa. St. Petersburg is a city in the country of Russia. Beijing is a city in the country of China. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Rome is a city in the country of Italy. Rio de Janeiro is a city in the country of Brazil. Hong Kong is a city in the country of China. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Bangkok is a city in the country of Thailand. Cape Town is a city in the country of South Africa. Paris is a city in the country of France. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Sydney is a city in the country of Australia. Beijing is a city in the country of China. San Francisco is a city in the country of United States. Hong Kong is a city in the country of',
#     'China'),
#    ('New Delhi is a city in the country of India. Rome is a city in the country of Italy. Hong Kong is a city in the country of China. Sydney is a city in the country of',
#     'Australia'),
#    ('Bangkok is a city in the country of Thailand. Hong Kong is a city in the country of China. Paris is a city in the country of France. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('San Francisco is a city in the country of United States. New York City is a city in the country of United States. Kuala Lumpur is a city in the country of Malaysia. Beijing is a city in the country of',
#     'China'),
#    ('Hong Kong is a city in the country of China. Buenos Aires is a city in the country of Argentina. Tokyo is a city in the country of Japan. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rio de Janeiro is a city in the country of Brazil. Rome is a city in the country of Italy. New York City is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Cape Town is a city in the country of South Africa. Paris is a city in the country of France. New York City is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('Rio de Janeiro is a city in the country of Brazil. Mexico City is a city in the country of Mexico. Rome is a city in the country of Italy. Toronto is a city in the country of',
#     'Canada'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Rio de Janeiro is a city in the country of Brazil. Sydney is a city in the country of Australia. New Delhi is a city in the country of',
#     'India'),
#    ('Toronto is a city in the country of Canada. Beijing is a city in the country of China. Rome is a city in the country of Italy. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Cape Town is a city in the country of South Africa. Paris is a city in the country of France. Toronto is a city in the country of Canada. Beijing is a city in the country of',
#     'China'),
#    ('Paris is a city in the country of France. Rome is a city in the country of Italy. Mexico City is a city in the country of Mexico. Tokyo is a city in the country of',
#     'Japan'),
#    ('Rio de Janeiro is a city in the country of Brazil. Buenos Aires is a city in the country of Argentina. Rome is a city in the country of Italy. Mexico City is a city in the country of',
#     'Mexico'),
#    ('New York City is a city in the country of United States. Buenos Aires is a city in the country of Argentina. Tokyo is a city in the country of Japan. Toronto is a city in the country of',
#     'Canada')],
#   'full_data': [('Los Angeles is a city in the country of United States. Sydney is a city in the country of Australia. St. Petersburg is a city in the country of Russia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('San Francisco is a city in the country of United States. Hong Kong is a city in the country of China. Beijing is a city in the country of China. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Toronto is a city in the country of Canada. New York City is a city in the country of United States. San Francisco is a city in the country of United States. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('New York City is a city in the country of United States. Beijing is a city in the country of China. San Francisco is a city in the country of United States. Hong Kong is a city in the country of',
#     'China'),
#    ('Mexico City is a city in the country of Mexico. Cape Town is a city in the country of South Africa. Beijing is a city in the country of China. Rome is a city in the country of',
#     'Italy'),
#    ('Buenos Aires is a city in the country of Argentina. Sydney is a city in the country of Australia. Bangkok is a city in the country of Thailand. New Delhi is a city in the country of',
#     'India'),
#    ('New York City is a city in the country of United States. Rome is a city in the country of Italy. Cape Town is a city in the country of South Africa. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Bangkok is a city in the country of Thailand. Sydney is a city in the country of Australia. St. Petersburg is a city in the country of Russia. Kuala Lumpur is a city in the country of',
#     'Malaysia'),
#    ('New Delhi is a city in the country of India. Rome is a city in the country of Italy. Bangkok is a city in the country of Thailand. Hong Kong is a city in the country of',
#     'China'),
#    ('Hong Kong is a city in the country of China. Paris is a city in the country of France. Rio de Janeiro is a city in the country of Brazil. New York City is a city in the country of',
#     'United States'),
#    ('Beijing is a city in the country of China. Rio de Janeiro is a city in the country of Brazil. Hong Kong is a city in the country of China. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('Bangkok is a city in the country of Thailand. Rio de Janeiro is a city in the country of Brazil. Sydney is a city in the country of Australia. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Sydney is a city in the country of Australia. Rome is a city in the country of Italy. Toronto is a city in the country of Canada. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Hong Kong is a city in the country of China. New York City is a city in the country of United States. San Francisco is a city in the country of United States. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('Rome is a city in the country of Italy. Toronto is a city in the country of Canada. Rio de Janeiro is a city in the country of Brazil. New York City is a city in the country of',
#     'United States'),
#    ('Bangkok is a city in the country of Thailand. Beijing is a city in the country of China. Mexico City is a city in the country of Mexico. New York City is a city in the country of',
#     'United States'),
#    ('Sydney is a city in the country of Australia. San Francisco is a city in the country of United States. Paris is a city in the country of France. Cape Town is a city in the country of',
#     'South Africa'),
#    ('Cape Town is a city in the country of South Africa. Kuala Lumpur is a city in the country of Malaysia. Rome is a city in the country of Italy. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('New York City is a city in the country of United States. San Francisco is a city in the country of United States. Toronto is a city in the country of Canada. Rio de Janeiro is a city in the country of',
#     'Brazil'),
#    ('New York City is a city in the country of United States. Tokyo is a city in the country of Japan. Mexico City is a city in the country of Mexico. Cape Town is a city in the country of',
#     'South Africa'),
#    ('Hong Kong is a city in the country of China. Mexico City is a city in the country of Mexico. Bangkok is a city in the country of Thailand. Los Angeles is a city in the country of',
#     'United States'),
#    ('Kuala Lumpur is a city in the country of Malaysia. Bangkok is a city in the country of Thailand. Rome is a city in the country of Italy. Sydney is a city in the country of',
#     'Australia'),
#    ('Hong Kong is a city in the country of China. Rome is a city in the country of Italy. San Francisco is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('Hong Kong is a city in the country of China. Sydney is a city in the country of Australia. Toronto is a city in the country of Canada. Paris is a city in the country of',
#     'France'),
#    ('Toronto is a city in the country of Canada. Rio de Janeiro is a city in the country of Brazil. Hong Kong is a city in the country of China. Rome is a city in the country of',
#     'Italy'),
#    ('New Delhi is a city in the country of India. Cape Town is a city in the country of South Africa. Kuala Lumpur is a city in the country of Malaysia. Rome is a city in the country of',
#     'Italy'),
#    ('St. Petersburg is a city in the country of Russia. Paris is a city in the country of France. San Francisco is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Bangkok is a city in the country of Thailand. Paris is a city in the country of France. Los Angeles is a city in the country of United States. Cape Town is a city in the country of',
#     'South Africa'),
#    ('St. Petersburg is a city in the country of Russia. Los Angeles is a city in the country of United States. Buenos Aires is a city in the country of Argentina. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Rio de Janeiro is a city in the country of Brazil. New Delhi is a city in the country of India. Tokyo is a city in the country of Japan. Los Angeles is a city in the country of',
#     'United States'),
#    ('Tokyo is a city in the country of Japan. San Francisco is a city in the country of United States. Bangkok is a city in the country of Thailand. Toronto is a city in the country of',
#     'Canada'),
#    ('Sydney is a city in the country of Australia. San Francisco is a city in the country of United States. Rio de Janeiro is a city in the country of Brazil. St. Petersburg is a city in the country of',
#     'Russia'),
#    ('Hong Kong is a city in the country of China. San Francisco is a city in the country of United States. St. Petersburg is a city in the country of Russia. Paris is a city in the country of',
#     'France'),
#    ('Paris is a city in the country of France. Los Angeles is a city in the country of United States. Tokyo is a city in the country of Japan. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Cape Town is a city in the country of South Africa. New Delhi is a city in the country of India. Mexico City is a city in the country of Mexico. Rome is a city in the country of',
#     'Italy'),
#    ('New York City is a city in the country of United States. St. Petersburg is a city in the country of Russia. New Delhi is a city in the country of India. Paris is a city in the country of',
#     'France'),
#    ('Toronto is a city in the country of Canada. Paris is a city in the country of France. Sydney is a city in the country of Australia. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Bangkok is a city in the country of Thailand. New York City is a city in the country of United States. San Francisco is a city in the country of United States. New Delhi is a city in the country of',
#     'India'),
#    ('Paris is a city in the country of France. Rio de Janeiro is a city in the country of Brazil. Toronto is a city in the country of Canada. Bangkok is a city in the country of',
#     'Thailand'),
#    ('Toronto is a city in the country of Canada. Rome is a city in the country of Italy. St. Petersburg is a city in the country of Russia. San Francisco is a city in the country of',
#     'United States'),
#    ('Mexico City is a city in the country of Mexico. Bangkok is a city in the country of Thailand. New Delhi is a city in the country of India. New York City is a city in the country of',
#     'United States'),
#    ('Toronto is a city in the country of Canada. Rome is a city in the country of Italy. Hong Kong is a city in the country of China. San Francisco is a city in the country of',
#     'United States'),
#    ('Rio de Janeiro is a city in the country of Brazil. Tokyo is a city in the country of Japan. Rome is a city in the country of Italy. Kuala Lumpur is a city in the country of',
#     'Malaysia'),
#    ('New Delhi is a city in the country of India. Rio de Janeiro is a city in the country of Brazil. New York City is a city in the country of United States. Buenos Aires is a city in the country of',
#     'Argentina'),
#    ('Tokyo is a city in the country of Japan. Rome is a city in the country of Italy. New York City is a city in the country of United States. Toronto is a city in the country of',
#     'Canada'),
#    ('New Delhi is a city in the country of India. Toronto is a city in the country of Canada. New York City is a city in the country of United States. Tokyo is a city in the country of',
#     'Japan'),
#    ('Kuala Lumpur is a city in the country of Malaysia. New Delhi is a city in the country of India. Cape Town is a city in the country of South Africa. Rome is a city in the country of',
#     'Italy'),
#    ('Buenos Aires is a city in the country of Argentina. Paris is a city in the country of France. Sydney is a city in the country of Australia. New York City is a city in the country of',
#     'United States'),
#    ('Los Angeles is a city in the country of United States. Toronto is a city in the country of Canada. San Francisco is a city in the country of United States. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Cape Town is a city in the country of South Africa. Sydney is a city in the country of Australia. Kuala Lumpur is a city in the country of Malaysia. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Los Angeles is a city in the country of United States. Buenos Aires is a city in the country of Argentina. Bangkok is a city in the country of Thailand. Hong Kong is a city in the country of',
#     'China'),
#    ('Mexico City is a city in the country of Mexico. Toronto is a city in the country of Canada. Sydney is a city in the country of Australia. Cape Town is a city in the country of',
#     'South Africa'),
#    ('San Francisco is a city in the country of United States. New York City is a city in the country of United States. Buenos Aires is a city in the country of Argentina. Rome is a city in the country of',
#     'Italy'),
#    ('San Francisco is a city in the country of United States. Beijing is a city in the country of China. New Delhi is a city in the country of India. Mexico City is a city in the country of',
#     'Mexico'),
#    ('Kuala Lumpur is a city in the country of Malaysia. New York City is a city in the country of United States. St. Petersburg is a city in the country of Russia. Sydney is a city in the country of',
#     'Australia'),
#    ('Los Angeles is a city in the country of United States. Bangkok is a city in the country of Thailand. Beijing is a city in the country of China. Cape Town is a city in the country of',
#     'South Africa'),
#    ('Bangkok is a city in the country of Thailand. Los Angeles is a city in the country of United States. Hong Kong is a city in the country of China. Tokyo is a city in the country of',
#     'Japan'),
#    ('Los Angeles is a city in the country of United States. St. Petersburg is a city in the country of Russia. New Delhi is a city in the country of India. Kuala Lumpur is a city in the country of',
#     'Malaysia'),
#    ('New York City is a city in the country of United States. Beijing is a city in the country of China. Rio de Janeiro is a city in the country of Brazil. Sydney is a city in the country of',
#     'Australia'),
# ...
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of flamingo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lion is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of flamingo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turquoise is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of cornmeal is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of cornmeal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of diamond is commonly expressed in "',
#     'millimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of pig is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of flamingo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of axe is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turquoise is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lime is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of pig is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of cornmeal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of cornmeal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of axe is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of cornmeal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of axe is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turquoise is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lime is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turquoise is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of saffron is commonly expressed in " millimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turquoise is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of axe is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lion is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of axe is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of saffron is commonly expressed in "',
#     'millimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lime is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of axe is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of diamond is commonly expressed in " millimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of flamingo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of saffron is commonly expressed in " millimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of pig is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of saffron is commonly expressed in " millimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of blackberry is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of diamond is commonly expressed in " millimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lion is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lion is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lime is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of violet is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lime is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of flamingo is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of bamboo is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of pig is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of charcoal is commonly expressed in "',
#     'centimeter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lion is commonly expressed in " meter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of diamond is commonly expressed in " millimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of lime is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of pig is commonly expressed in "',
#     'meter'),
#    ('Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of gopher is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of starfish is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of turmeric is commonly expressed in " centimeter. Considering the following units " millimeter ", " centimeter ", " meter ", and " kilometer ", the size of diamond is commonly expressed in "',
#     'millimeter')]}}

# %%
fin = {}   

for key in full_data.keys():
    fin[key] = {
        "accuracy": accuracies[key],
        "retained": retained_pyt[key],
        "full_data": full_data[key],
    }

with open(f"{model_name.split('/')[-1]}_prompt_data.pkl", "wb") as f:
    pickle.dump(fin, f)

# %%
# Print a recap of the results
for key, value in data.items():
    print(f"Accuracy for {key}: {value['accuracy']}")
    print("\n")
    print("---------------------------------------------------")
